# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=true')
t1 = r.text

import json
data = json.loads(t1)

print(len(data))
# Out:
# 30

# %%
data
# Out:
# [{'id': 225578807,
#   'title': '<請先點我> 工作板＆實習、打工職缺刊登說明',
#   'excerpt': '工作板主要供分享職場工作心得、面試、正職、招考過程分享、各類型工作內容介紹、勞工工作權益與相關法案議題討論相關文章。文章發文後請加上話題，如：經驗分享、職業介紹、勞工權益、徵才等....，「實習職缺/刊登」請點：',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': True,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2017-01-01T06:27:39.650Z',
#   'updatedAt': '2018-07-27T00:18:35.980Z',
#   'commentCount': 34,
#   'likeCount': 664,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['工作板', 'Dcard公告', '實習職缺', '打工職缺'],
#   'meta': {},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'D',
#   'school': '客服小天使',
#   'department': 'dcard_support_2',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 662},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232685539,
#   'title': '自己創造錢多事少離家近的工作',
#   'excerpt': '小弟今年28歲，高中畢業後便一直四處找工作.換工作，苦苦尋求能夠讓自己滿意的工作環境及薪水，直到幾年前的某天自己突然有了一個大膽的想法，唯一無靠的我，賺錢只是為了生活，一個月5萬6萬即可滿足，既然無法',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T12:17:09.866Z',
#   'updatedAt': '2019-12-14T12:17:09.866Z',
#   'commentCount': 52,
#   'likeCount': 101,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['創造', '工作', '職業介紹', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 100},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683109,
#   'title': '補習班老闆不給回家投票怎辦',
#   'excerpt': '我是桃園人在高雄唸書，今年是首投族，我是在國中小補習班當工讀生，平常他叫我星期六或星期天去幫忙我就算了，我工作2年時薪還是150也就算了，剛剛去跟他說我1/11想回家投票，老闆直接斬釘截鐵的說不行，國',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T02:17:32.369Z',
#   'updatedAt': '2019-12-14T02:17:32.369Z',
#   'commentCount': 24,
#   'likeCount': 65,
#   'withNickname': True,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['投票', '老闆', '打工', '慣老闆', '補習班'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'school': '胖胖得',
#   'department': 'pong_pong_der',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 65}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232687292,
#   'title': '怎麼回應面試官的質疑？',
#   'excerpt': '發這篇的用意主要是想問問大家的看法，——文章開始——，前陣子我去某公司面試，我的語文能力（多益）比較突出，說高不高600初頭而已，在面試的過程中，我覺得我的表現沒有很好，當面試官看到我的多益分數時，他',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T17:05:46.809Z',
#   'updatedAt': '2019-12-14T17:08:09.877Z',
#   'commentCount': 18,
#   'likeCount': 13,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['面試', '面試經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 13}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232687543,
#   'title': '#經驗分享 高雄某電商美編🖥',
#   'excerpt': '我目前在高雄一家賣保養品的小電商工作，薪資28000（含全勤1000），勞健保1200，福利金100，時間 10：00--18：30，全年無休，國定假日也上班，過年只放除夕、初一，不能請假，只能調假，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T17:46:50.872Z',
#   'updatedAt': '2019-12-14T17:46:50.872Z',
#   'commentCount': 3,
#   'likeCount': 10,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['工作經驗', '工作', '薪資', '離職', '職業介紹'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'school': '樓下有隻熊',
#   'department': 'megumi02',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '620405dc-d991-4251-9a76-600da59cc4fa',
#     'url': 'https://i.imgur.com/abV1MOnl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/abV1MOnl.jpg',
#     'thumbnail': 'https://i.imgur.com/abV1MOnl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-14T17:46:50.872Z',
#     'updatedAt': '2019-12-14T17:46:50.872Z'},
#    {'id': '620405dc-d991-4251-9a76-600da59cc4fa',
#     'url': 'https://i.imgur.com/abV1MOn.jpg',
#     'normalizedUrl': 'https://imgur.com/abV1MOn',
#     'thumbnail': 'https://i.imgur.com/abV1MOnl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-14T17:46:50.872Z',
#     'updatedAt': '2019-12-14T17:46:50.872Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 10}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/abV1MOn.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683264,
#   'title': '網路影片行情',
#   'excerpt': '因為最近公司想拍三隻類似這群人「過年服務業大暴走」的影片三隻，演員由我司提供，不需特別妝髮，場地在我司佈置，若無法則可向外租借另計價錢，腳本由接案者提供，拍攝及後製（剪接、上字幕、簡單字卡不須特效），',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T03:14:54.093Z',
#   'updatedAt': '2019-12-14T03:14:54.093Z',
#   'commentCount': 0,
#   'likeCount': 10,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['薪資', '行情', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3c338dc6-7d68-4f07-b94c-593b4b5acca0',
#     'url': 'https://youtu.be/j0yxPWsVk5s',
#     'normalizedUrl': 'https://www.youtube.com/watch?v=j0yxPWsVk5s',
#     'thumbnail': 'https://img.youtube.com/vi/j0yxPWsVk5s/hqdefault.jpg',
#     'type': 'video/youtube',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-14T03:14:54.093Z',
#     'updatedAt': '2019-12-14T03:14:54.093Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 10}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683921,
#   'title': '高雄好找工作嗎',
#   'excerpt': '求救我不知道到底該怎麼辦，每天就是找工作，更新了也沒有想要的工作，好想快點找到工作，又不知道自己的興趣在哪',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T06:24:09.065Z',
#   'updatedAt': '2019-12-14T06:24:09.065Z',
#   'commentCount': 21,
#   'likeCount': 9,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['高雄', '求職', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'school': "Wei ฅ'ω'ฅ",
#   'department': 'ling_wei',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 9}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232690093,
#   'title': '讓我很不安的工作',
#   'excerpt': '我是今年應屆，到公司上班三個禮拜了，但還是一直覺得很多事情都做不好，稍微說一下公司情況，業務助理加我總共四個，包含一個主管，然後助理們都超忙更不用說主管，我是主管教的不過因為位置有距離所以我更常問我旁',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T09:19:47.798Z',
#   'updatedAt': '2019-12-15T09:19:47.798Z',
#   'commentCount': 3,
#   'likeCount': 6,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['工作', '不安'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'adf760e2-046e-4554-afd1-aecf5937b440',
#     'url': 'https://i.imgur.com/xe598W2l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/xe598W2l.jpg',
#     'thumbnail': 'https://i.imgur.com/xe598W2l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-15T09:19:47.798Z',
#     'updatedAt': '2019-12-15T09:19:47.798Z'},
#    {'id': 'adf760e2-046e-4554-afd1-aecf5937b440',
#     'url': 'https://i.imgur.com/xe598W2.jpg',
#     'normalizedUrl': 'https://imgur.com/xe598W2',
#     'thumbnail': 'https://i.imgur.com/xe598W2l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-15T09:19:47.798Z',
#     'updatedAt': '2019-12-15T09:19:47.798Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 6}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/xe598W2.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683359,
#   'title': '百貨工作 大魯閣',
#   'excerpt': '請問在板上有人在大魯閣百貨工作的嗎？他們有沒有提供員工餐啊，還是說是出示證件可以打折那種方式呢，\u200d️\u200d️感謝',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T03:44:36.718Z',
#   'updatedAt': '2019-12-14T03:44:36.718Z',
#   'commentCount': 3,
#   'likeCount': 6,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['大魯閣', '百貨', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 6}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232687094,
#   'title': '新加坡人想到台灣工作',
#   'excerpt': '我是新加坡人，想要到台灣打工。做短期的工作，想要體驗生活吧。打算 4月到7月 到台灣打工！ 實習之類的吧，看什麼合適。我還沒上大學，有 diploma 文凭。。。今年20岁。想在被大學生活捆綁4年之前',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T16:33:44.326Z',
#   'updatedAt': '2019-12-14T16:33:44.326Z',
#   'commentCount': 7,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['新加坡人', '工作', '求職', '實習', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683252,
#   'title': '壓力大到會傷害自己',
#   'excerpt': '抱歉打擾了，我想問問大家…，如果在面對工作的壓力因真的難以負荷會開始去每天回家一直哭（在上班超級壓抑，只有回家才能徹底放鬆），還有各種傷害自己…，雖然講出來覺得很丟臉，我情緒一堆積起來就會難過到不行…',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T03:12:31.904Z',
#   'updatedAt': '2019-12-14T03:12:31.904Z',
#   'commentCount': 6,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['壓力', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232689443,
#   'title': '隔壁部門不熟的同事加了我好友又封鎖我😨',
#   'excerpt': '事情是這樣的，某天早上我收到來自隔壁部門同事的臉書交友邀請。是一個我進入公司快一年大概沒說超過五句話的不熟同事，但因為我比較菜也沒膽不加，就按了同意。結果到晚上我發現我被她刪除好友+封鎖，我整個？？？',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T06:46:21.274Z',
#   'updatedAt': '2019-12-15T06:46:21.274Z',
#   'commentCount': 7,
#   'likeCount': 4,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['同事', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232685913,
#   'title': '想了解一下餐飲業的生態（時數、薪資）',
#   'excerpt': '在餐飲業上班的各位，我想了解 大家的，1.（時薪？ 薪資？ 上班時數？ 月休天數？ 內外場？ 勞健保 ？加班費？），2.有的是補休時數 ？3.通常薪資單會有什麼項目？不是連鎖企業好像幾乎都沒有勞健保齁',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T13:24:46.221Z',
#   'updatedAt': '2019-12-14T13:24:46.221Z',
#   'commentCount': 3,
#   'likeCount': 4,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['餐飲業', '時數', '薪資', '工作', '實習'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232684286,
#   'title': '到職日當月薪資怎麼算',
#   'excerpt': '如題，想請對勞基法有研究的幫忙回答，當初進這間公司時我是11號才報到，結果收到當月薪資單時公司直接扣掉我1萬塊薪資（月薪算28k，扣完剩17k多），詢問後公司說是系統問題，（系統默認我1到10號算曠職',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T07:46:45.968Z',
#   'updatedAt': '2019-12-14T07:46:45.968Z',
#   'commentCount': 6,
#   'likeCount': 4,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['薪資', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232690169,
#   'title': '上班力不從心，做什麼沒人教',
#   'excerpt': '第一份工作快待5個月了，公司氣氛很糟，主管把事情推給能解決的人，剩下的人每天上班發呆也沒關係，最近被主管丟了一堆工作，但我從進公司就沒人教導我業務流程面的工作，當流程有問題我應該怎樣。我是軟體工程師，',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T09:38:42.022Z',
#   'updatedAt': '2019-12-15T09:40:33.414Z',
#   'commentCount': 0,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['上班', '工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232686890,
#   'title': '兩份工作該選哪個',
#   'excerpt': '一份是離家較近 約25分鐘，薪水較穩定N+5000～8000（一定會拿到），但耗體力，上班比較不自由，不能用手機要站好站滿，品項較有興趣 但工作內容基本上就是打雜，（在職中），*補充：因風氣關係基本上',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T16:01:01.804Z',
#   'updatedAt': '2019-12-15T03:08:30.616Z',
#   'commentCount': 5,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['工作', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232685755,
#   'title': '年薪算法詢問',
#   'excerpt': '不好意思....想問一下年薪究竟是怎麼算的，問了身邊幾個朋友他們也不確定，假設我每個月薪水3萬4，今年Q1拿到「去年」的年終兩個月，今年Q3拿到「去年」個人績效獎金，我今年的年薪就是3萬4*12加上 ',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T12:53:56.268Z',
#   'updatedAt': '2019-12-14T12:53:56.268Z',
#   'commentCount': 2,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['年薪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232684746,
#   'title': '富邦IA說明會',
#   'excerpt': '有人今天有去嗎，覺得如何QQ，可以討論一下XDD，好像大家學歷都很好（？）',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T09:40:20.044Z',
#   'updatedAt': '2019-12-14T09:40:20.044Z',
#   'commentCount': 6,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['Arm', '工作', '富邦', '銀行', '面試'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232684347,
#   'title': '永豐餘人資管理師',
#   'excerpt': '上禮拜收到永豐餘（新屋廠）的人資管理師面試邀約（說是人資但工作內容偏行政一點），原本經過各方考量後（交通便利性..等），回電拒絕邀約，但對方態度好好說：「真的要放棄嗎！這是很難得的機會餒畢竟我們很少開',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T08:01:57.336Z',
#   'updatedAt': '2019-12-14T08:17:45.782Z',
#   'commentCount': 5,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['群創', '永豐餘', '人資', '工作', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683307,
#   'title': '家×福打工...',
#   'excerpt': '想請問版上的各位，有沒有人在家×福的網購課待過，（沒待過的也沒關係）可以分享工作內容給我知道嗎？因為有在人力銀行看到它們要徵寒假工讀，想去應徵，但目前有2個部門在考慮，一個是收銀課，一個是網購課，想請',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T03:24:49.689Z',
#   'updatedAt': '2019-12-14T03:24:49.689Z',
#   'commentCount': 5,
#   'likeCount': 3,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['工作經驗', '打工', '家樂福'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232690343,
#   'title': '工作選擇（請益',
#   'excerpt': '收到兩間公司通知，但猶豫該選哪間，1.傳產，員工100多人，職務為主管助理，距離：騎車15分鐘，薪水27k，三個月後調為32k，週休二日，但常加班有加班費，面試時主管有提到認識前前東家公司的業務，感覺',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T10:17:19.389Z',
#   'updatedAt': '2019-12-15T10:38:17.860Z',
#   'commentCount': 2,
#   'likeCount': 2,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['工作', '面試', '求職'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232689889,
#   'title': 'GPA沒這麼重要吧',
#   'excerpt': '社交實力比較重要 當然GPA不能太爛，我想他們寧可選一個討人喜歡的人也不會選一個GPA 4.3然後什麼都不會的人，都大學了，想法該改變了，最頂尖的公司GPA要很好沒錯，但如果你只想要吃飽溫飽，學歷在第',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T08:32:50.809Z',
#   'updatedAt': '2019-12-15T08:37:30.069Z',
#   'commentCount': 5,
#   'likeCount': 2,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['工作'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232689465,
#   'title': '直營房屋的面試',
#   'excerpt': '黃黃的招牌傳送面試通知，去到信義區的大樓內一眼望去座位大概有80多人，在位子上修改自己的履歷，形形色色的人都有...叫號面試，1.自我介紹，2.工作經歷（畢業後一分一毫不差的要你全部說出在幹嘛），3.',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T06:51:16.578Z',
#   'updatedAt': '2019-12-15T06:51:16.578Z',
#   'commentCount': 0,
#   'likeCount': 2,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['面試經驗', '面試', '房屋', '面試心得'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'school': '腳底養',
#   'department': 'giudiyoung',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232687812,
#   'title': '請教',
#   'excerpt': '想知道對於畫畫（手繪）、平面設計方面有興趣的 適合什麼工作或從方向開始著手會比較加分，本身 高中是商科 大學行銷系，一直覺得沒有學以致用、很專精於什麼專業上，喜歡插畫的東西 也努力學習畫畫 收集作品，',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T18:38:44.724Z',
#   'updatedAt': '2019-12-14T18:38:44.724Z',
#   'commentCount': 0,
#   'likeCount': 2,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['工作', '求職', '薪資', '工作經驗', '履歷'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232683794,
#   'title': '詢問 公務人員 回扣',
#   'excerpt': '請問如果是公家機關，購買用團體獎金訂購食物（麥當勞、肯德基），用個人會員集點（可以換商品），是否有違法之虞，上網搜尋 都沒有太清楚的答案，麻煩各位解答了...謝謝...',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-14T05:49:26.615Z',
#   'updatedAt': '2019-12-14T09:34:09.111Z',
#   'commentCount': 4,
#   'likeCount': 2,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['公務人員', '回扣'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232690634,
#   'title': '新創公司 博弈產業',
#   'excerpt': '想問有沒有人有經驗可以分享面試經驗？我收到了面試通知信，他們的薪水起跳較高，但上網爬文發現公司的資訊非常少，說是遊戲開發公司，但就是開發博弈遊戲，投入博弈產業是否有點危險…？可以的話，也希望有人可以分',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T11:13:11.389Z',
#   'updatedAt': '2019-12-15T11:13:11.389Z',
#   'commentCount': 2,
#   'likeCount': 1,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['新創', '工作經驗', '面試經驗', '博弈'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232690305,
#   'title': '台灣悅廷和 詢問',
#   'excerpt': '想請問板上有沒有前輩有面試過這間醫療器材相關的公司，想詢問整場面試下來大概多久以及該注意的事項～麻煩大家了！因為網路上關於這間公司的資訊真的很少',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T10:06:02.592Z',
#   'updatedAt': '2019-12-15T10:06:02.592Z',
#   'commentCount': 0,
#   'likeCount': 1,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['工作', '面試', '工作經驗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232689518,
#   'title': '如下',
#   'excerpt': '',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': 232689452,
#   'createdAt': '2019-12-15T07:07:20.331Z',
#   'updatedAt': '2019-12-15T07:07:20.331Z',
#   'commentCount': 0,
#   'likeCount': 1,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['英文', '家教', '打工職缺'],
#   'meta': {'crossPostId': 232689452},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'M',
#   'school': '中華民國陸軍專科學校',
#   'replyTitle': '誠徵英文家教',
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232689451,
#   'title': '全家打工',
#   'excerpt': '在1111看到中和區職缺，總公司的人叫我在中和區的店面試，想問面試完了通知要等多久呢？沒錄取不會有通知？',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T06:48:59.329Z',
#   'updatedAt': '2019-12-15T06:48:59.329Z',
#   'commentCount': 3,
#   'likeCount': 1,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['全家', '打工', '面試'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'school': '中國科技大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232688960,
#   'title': '#卡達 12/15面試',
#   'excerpt': '大家好～～很開心參與這次的面試，這是我第五次了，考官看起來笑笑的但是依舊請我等晚上八點的通知～我是不是沒有希望了？還是我要在台北等到八點呢？工作在南部明早是早班好猶豫要不要留下來等待呀 每年的規則好像',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444',
#   'replyId': None,
#   'createdAt': '2019-12-15T04:43:02.258Z',
#   'updatedAt': '2019-12-15T04:43:02.258Z',
#   'commentCount': 3,
#   'likeCount': 1,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['面試', '卡達'],
#   'meta': {'layout': 'classic'},
#   'forumName': '工作',
#   'forumAlias': 'job',
#   'gender': 'F',
#   'school': '銘傳大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''}]

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for d in data:
    print(d['title'])
    print(d['createdAt'])
    print(d['commentCount'])
    print(d['likeCount'])
# Out:
# <請先點我> 工作板＆實習、打工職缺刊登說明
# 2017-01-01T06:27:39.650Z
# 34
# 664
# 自己創造錢多事少離家近的工作
# 2019-12-14T12:17:09.866Z
# 52
# 101
# 補習班老闆不給回家投票怎辦
# 2019-12-14T02:17:32.369Z
# 24
# 65
# 怎麼回應面試官的質疑？
# 2019-12-14T17:05:46.809Z
# 18
# 13
# #經驗分享 高雄某電商美編🖥
# 2019-12-14T17:46:50.872Z
# 3
# 10
# 網路影片行情
# 2019-12-14T03:14:54.093Z
# 0
# 10
# 高雄好找工作嗎
# 2019-12-14T06:24:09.065Z
# 21
# 9
# 讓我很不安的工作
# 2019-12-15T09:19:47.798Z
# 3
# 6
# 百貨工作 大魯閣
# 2019-12-14T03:44:36.718Z
# 3
# 6
# 新加坡人想到台灣工作
# 2019-12-14T16:33:44.326Z
# 7
# 5
# 壓力大到會傷害自己
# 2019-12-14T03:12:31.904Z
# 6
# 5
# 隔壁部門不熟的同事加了我好友又封鎖我😨
# 2019-12-15T06:46:21.274Z
# 7
# 4
# 想了解一下餐飲業的生態（時數、薪資）
# 2019-12-14T13:24:46.221Z
# 3
# 4
# 到職日當月薪資怎麼算
# 2019-12-14T07:46:45.968Z
# 6
# 4
# 上班力不從心，做什麼沒人教
# 2019-12-15T09:38:42.022Z
# 0
# 3
# 兩份工作該選哪個
# 2019-12-14T16:01:01.804Z
# 5
# 3
# 年薪算法詢問
# 2019-12-14T12:53:56.268Z
# 2
# 3
# 富邦IA說明會
# 2019-12-14T09:40:20.044Z
# 6
# 3
# 永豐餘人資管理師
# 2019-12-14T08:01:57.336Z
# 5
# 3
# 家×福打工...
# 2019-12-14T03:24:49.689Z
# 5
# 3
# 工作選擇（請益
# 2019-12-15T10:17:19.389Z
# 2
# 2
# GPA沒這麼重要吧
# 2019-12-15T08:32:50.809Z
# 5
# 2
# 直營房屋的面試
# 2019-12-15T06:51:16.578Z
# 0
# 2
# 請教
# 2019-12-14T18:38:44.724Z
# 0
# 2
# 詢問 公務人員 回扣
# 2019-12-14T05:49:26.615Z
# 4
# 2
# 新創公司 博弈產業
# 2019-12-15T11:13:11.389Z
# 2
# 1
# 台灣悅廷和 詢問
# 2019-12-15T10:06:02.592Z
# 0
# 1
# 如下
# 2019-12-15T07:07:20.331Z
# 0
# 1
# 全家打工
# 2019-12-15T06:48:59.329Z
# 3
# 1
# #卡達 12/15面試
# 2019-12-15T04:43:02.258Z
# 3
# 1

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
# 熱門
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data), likeCount/len(data))

#非熱門
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=false')
response = r.text
data = json.loads(response)
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data), likeCount/len(data))
# Out:
# 3.066666666666667 1.9
# 3.066666666666667 1.9

# %%
a=[1,2,3,4,5]
c=0
for b in a:
    c += 1
c
# Out:
# 5

# %%
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data), likeCount/len(data))
print(commentCount)
# Out:
# 3.066666666666667 1.9
# 92

# %%
for d in data:
    print(d['commentCount'])
# Out:
# 3
# 0
# 1
# 2
# 0
# 1
# 1
# 2
# 0
# 0
# 3
# 0
# 5
# 0
# 0
# 3
# 7
# 0
# 0
# 3
# 0
# 19
# 1
# 0
# 3
# 4
# 4
# 18
# 0
# 12
